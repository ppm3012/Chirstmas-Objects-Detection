# %% [markdown]
# ## Insert Repo and Custom Dataset

# %%
# %%capture
# !git clone https://github.com/ultralytics/yolov5.git
# !curl -L "https://app.roboflow.com/ds/Shz7Lx2frG?key=YWkj112nrf" > roboflow.zip; unzip -o roboflow.zip; rm roboflow.zip
# !pip install -r requirements.txt
# !pip install wandb
# %cd /content/yolov5

# %% [markdown]
# ## Train

# %%
# !python train.py \
  --data ../data.yaml \
  --epochs 80 \
  --project yolo-wandb-demo \
  --upload_dataset \
  --bbox_interval 1 \
  --save-period 1
# Out:
# wandb: Currently logged in as: ppm_jan (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=../data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=80, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolo-wandb-demo, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=1, local_rank=-1, entity=None, upload_dataset=True, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/detect/exp7/88_jpg.rf.ac1b39b82584eda3780d74561906b2a8.jpg', width=700)
# Out:
# GROUND TRUTH TRAINING DATA:

# %% [markdown]
# ## Testing

# %%
from IPython.display import Image
# !python detect.py --source /content/test/images --weights /content/yolov5/yolov5s.pt --img 416 --save-txt --save-conf
# Out:
# detect: weights=['/content/yolov5/yolov5s.pt'], source=/content/test/images, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/10 /content/test/images/11_jpg.rf.778e9e89f0d3625d74909575ab05fd94.jpg: 416x416 1 couch, 1 potted plant, Done. (0.029s)
# image 2/10 /content/test/images/12_jpg.rf.a83f61cb15fba80ee6fe3bc8ca34ac82.jpg: 416x416 Done. (0.029s)
# image 3/10 /content/test/images/30_png.rf.472ded5fd504995a4c8aa5bd51abab73.jpg: 416x416 1 person, Done. (0.029s)
# ...

# %%
Image(filename='/content/yolov5/runs/detect/exp11/83_jpg.rf.f0603c39ed7ece22e0a480ec186f6c80.jpg')
